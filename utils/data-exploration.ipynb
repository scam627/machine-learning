# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./sample-data/california_housing_train.csv')
print(df) #dataframe
df.head(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#           longitude      latitude  ...  median_income  median_house_value
# count  17000.000000  17000.000000  ...   17000.000000        17000.000000
# mean    -119.562108     35.625225  ...       3.883578       207300.912353
# std        2.005166      2.137340  ...       1.908157       115983.764387
# min     -124.350000     32.540000  ...       0.499900        14999.000000
# 25%     -121.790000     33.930000  ...       2.566375       119400.000000
# 50%     -118.490000     34.250000  ...       3.544600       180400.000000
# 75%     -118.000000     37.720000  ...       4.767000       265000.000000
# max     -114.310000     41.950000  ...      15.000100       500001.000000
#
# [8 rows x 9 columns]

# %%
df.hist(bins=50,figsize=(10,10))
plt.show()

# %%
df.plot(kind='scatter',x='longitude',y='latitude',alpha=0.5,s=df['median_income']*10,c=df['median_house_value'],colorbar=True,cmap=plt.get_cmap('jet'))
plt.show()

# %%
pd.plotting.scatter_matrix(df,figsize=(20,20))
plt.show()

# %%
df.corr()
# Out:
#                     longitude  latitude  ...  median_income  median_house_value
# longitude            1.000000 -0.925208  ...      -0.015485           -0.044982
# latitude            -0.925208  1.000000  ...      -0.080303           -0.144917
# housing_median_age  -0.114250  0.016454  ...      -0.115932            0.106758
# total_rooms          0.047010 -0.038773  ...       0.195383            0.130991
# total_bedrooms       0.071802 -0.069373  ...      -0.013495            0.045783
# population           0.101674 -0.111261  ...      -0.000638           -0.027850
# households           0.059628 -0.074902  ...       0.007644            0.061031
# median_income       -0.015485 -0.080303  ...       1.000000            0.691871
# median_house_value  -0.044982 -0.144917  ...       0.691871            1.000000
#
# [9 rows x 9 columns]

# %% [markdown]
# En el siguiente bloque se muestra como seleccionar y eliminar variables de un dataframe

# %%
long = df['longitude']
long.describe()
# Out:
# count    17000.000000
# mean      -119.562108
# std          2.005166
# min       -124.350000
# 25%       -121.790000
# 50%       -118.490000
# 75%       -118.000000
# max       -114.310000
# Name: longitude, dtype: float64

# %%
new_df = df.drop(columns='longitude')
new_df.describe()
# Out:
#            latitude  housing_median_age  ...  median_income  median_house_value
# count  17000.000000        17000.000000  ...   17000.000000        17000.000000
# mean      35.625225           28.589353  ...       3.883578       207300.912353
# std        2.137340           12.586937  ...       1.908157       115983.764387
# min       32.540000            1.000000  ...       0.499900        14999.000000
# 25%       33.930000           18.000000  ...       2.566375       119400.000000
# 50%       34.250000           29.000000  ...       3.544600       180400.000000
# 75%       37.720000           37.000000  ...       4.767000       265000.000000
# max       41.950000           52.000000  ...      15.000100       500001.000000
#
# [8 rows x 8 columns]
